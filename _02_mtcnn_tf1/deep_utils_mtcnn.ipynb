# %% [markdown]
# <a href="https://colab.research.google.com/github/pooya-mohammadi/Face/blob/master/_02_mtcnn_tf1/deep_utils_mtcnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep-Utils
# ## A toolkit for deep-learning practitioners!
#
# This repository contains the most frequently used deep learning models and functions. Deep_Utils is still under heavy development, so take into consideration that many features may change in the future. Install the latest version using pypi.

# %% [markdown]
# # Installation

# %%
# !pip install deep_utils
# !pip install -U opencv-python
# Out:
# Requirement already satisfied: deep_utils in /usr/local/lib/python3.7/dist-packages (0.8.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deep_utils) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from deep_utils) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from deep_utils) (2.23.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from deep_utils) (4.5.4.60)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->deep_utils) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->deep_utils) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->deep_utils) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->deep_utils) (1.24.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.5.4.60)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)

# %% [markdown]
# ## MTCNN-Pytorch

# %%
from deep_utils import face_detector_loader, list_face_detection_models
    
# This line will print all the available models 
print(list_face_detection_models())
# Out:
# /usr/local/lib/python3.7/dist-packages/deep_utils/vision/face_detection/ultralight/__init__.py:5: UserWarning:
# No module named 'deep_utils.vision.face_detection.ultralight.torch'. If you don't use UltralightTorchFaceDetector ignore this message.
#   'UltralightTorchFaceDetector')
# /usr/local/lib/python3.7/dist-packages/deep_utils/vision/face_detection/ultralight/__init__.py:8: UserWarning:
# No module named 'deep_utils.vision.face_detection.ultralight.tf'. If you don't use UltralightTFFaceDetector ignore this message.
#   'UltralightTFFaceDetector')
# SSDCV2CaffeFaceDetector
# MTCNNTorchFaceDetector
# HaarcascadeCV2FaceDetector
# MTCNNTFFaceDetector
# UltralightTorchFaceDetector
# UltralightTFFaceDetector
# RetinaFaceTorchFaceDetector

# %% [markdown]
# ## Create a face detection model using MTCNN-Torch
# The weight will be downloaded automatically

# %%
face_detector = face_detector_loader('MTCNNTorchFaceDetector')

# %% [markdown]
# # Check the input config

# %%
face_detector
# Out:
# MTCNNTorchFaceDetector config attributes:
# confidence = 0.8
# device = cpu
# download_variables = ('pnet', 'onet', 'rnet')
# factor = 0.707
# min_detection_size = 12
# min_face_size = 20.0
# nms_thresholds = (0.7, 0.7, 0.7)
# onet = /root/.deep_utils/weights/vision/face_detection/mtcnn/torch/onet.npy
# onet_cache = weights/vision/face_detection/mtcnn/torch/onet.npy
# onet_url = https://github.com/Practical-AI/deep_utils/releases/download/0.1.0/onet.npy
# pnet = /root/.deep_utils/weights/vision/face_detection/mtcnn/torch/pnet.npy
# pnet_cache = weights/vision/face_detection/mtcnn/torch/pnet.npy
# pnet_url = https://github.com/Practical-AI/deep_utils/releases/download/0.1.0/pnet.npy
# rnet = /root/.deep_utils/weights/vision/face_detection/mtcnn/torch/rnet.npy
# rnet_cache = weights/vision/face_detection/mtcnn/torch/rnet.npy
# rnet_url = https://github.com/Practical-AI/deep_utils/releases/download/0.1.0/rnet.npy
# thresholds = (0.6, 0.7, 0.8)

# %% [markdown]
# # Download the test image

# %%
import cv2
from deep_utils import show_destroy_cv2, Box, download_file, Point
from PIL import Image

# Download an image
download_file("https://raw.githubusercontent.com/pooya-mohammadi/deep_utils/master/examples/vision/data/movie-stars.jpg")

# Load an image
img = cv2.imread("movie-stars.jpg")

# pil.Image is used for visualization
Image.fromarray(img[...,::-1]) # convert to rgb
# Out:
# Downloading data from https://raw.githubusercontent.com/pooya-mohammadi/deep_utils/master/examples/vision/data/movie-stars.jpg
# [██████████████████████████████████████████████████]
# <PIL.Image.Image image mode=RGB size=1000x602 at 0x7F3D7C861610>

# %% [markdown]
# # Detect faces

# %%
# Detect the faces
result = face_detector.detect_faces(img, is_rgb=False)

# Draw detected boxes on the image.
img = Box.put_box(img, result.boxes)

# Draw the landmarks
for landmarks in result.landmarks:
    Point.put_point(img, list(landmarks.values()), radius=3)

# pil.Image is used for visualization
Image.fromarray(img[...,::-1]) # convert to rgb
# Out:
# /usr/local/lib/python3.7/dist-packages/deep_utils/vision/face_detection/mtcnn/torch/src/get_nets.py:70: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   a = F.softmax(a)
# /usr/local/lib/python3.7/dist-packages/deep_utils/vision/face_detection/mtcnn/torch/src/get_nets.py:113: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   a = F.softmax(a)
# /usr/local/lib/python3.7/dist-packages/deep_utils/vision/face_detection/mtcnn/torch/src/get_nets.py:164: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   a = F.softmax(a)
# <PIL.Image.Image image mode=RGB size=1000x602 at 0x7F3D7B3EB8D0>

# %% [markdown]
# # Check out our repo
# [link https://github.com/pooya-mohammadi/deep_utils](https://https://github.com/pooya-mohammadi/deep_utils)
#
# # Please give the repo a ***star***
